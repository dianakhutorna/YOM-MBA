# %% [markdown]
# # Prototyping

# %%
import pandas as pd
import numpy as np
print("Всё работает!")
# Out:
# Всё работает!

# %%
import sys
import os

# добавляем корень проекта в sys.path
sys.path.append(os.path.abspath(".."))

from src.db import save_result
# Out:
# MongoDB подключена успешно!

# %%
save_result({
    "model": "RandomForest",
    "accuracy": 0.91,
    "params": {"n_estimators": 150}
})
# Out:
# ObjectId('692f30bdfffc93b658bdc482')

# %%
from src.db import collection

for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('692f30bdfffc93b658bdc482'), 'model': 'RandomForest', 'accuracy': 0.91, 'params': {'n_estimators': 150}}
